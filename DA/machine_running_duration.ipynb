# %% [markdown]
# # Loading into Pandas

# %%
import pandas as pd
mrd = pd.read_csv('machine_running_duration.csv', delimiter = ',')
print(mrd)

import matplotlib.pyplot as plt

mrd.plot(kind = 'bar', x = 'machine', y = 'Running time', title = 'Machine Running Duration')

# plt.title('Machine Running Duration')

# plt.xlabel('machine')
# plt.ylabel('Running time')

plt.show()
# Out:
#      machine  Running time
# 0  machine_1           300
# 1  machine_2           420
# 2  machine_3           750
# 3  machine_4           860
