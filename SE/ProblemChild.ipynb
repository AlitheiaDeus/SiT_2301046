# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
from matplotlib import pyplot as plt
import seaborn as sns

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('RainfallMonthlyNumberofRainDays.csv')

# display(df)

df[['yyyy', 'mm']] = df['month'].str.split('-', expand=True)

del df['month']

df['yyyy'] = df['yyyy'].astype(int)
df['mm'] = df['mm'].astype(int)
df['no_of_rainy_days'] = df['no_of_rainy_days'].astype(int)

display(df)
# Out:
#      no_of_rainy_days  yyyy  mm
# 0                  10  1982   1
# 1                   5  1982   2
# 2                  11  1982   3
# 3                  14  1982   4
# 4                  10  1982   5
# 5                   8  1982   6
# 6                   8  1982   7
# 7                  11  1982   8
# 8                   9  1982   9
# 9                  10  1982  10
# 10                 13  1982  11
# 11                 21  1982  12
# 12                 18  1983   1
# 13                  2  1983   2
# 14                  2  1983   3
# 15                  4  1983   4
# 16                 11  1983   5
# 17                 11  1983   6
# 18                 18  1983   7
# 19                 10  1983   8
# 20                 18  1983   9
# 21                 17  1983  10
# 22                 18  1983  11
# 23                 16  1983  12
# 24                 18  1984   1
# 25                 19  1984   2
# 26                 19  1984   3
# 27                 17  1984   4
# ...

# %%
# ys = df['yyyy'].unique()
# ms = df['mm'].unique()

# df_des = {}

# for y in ys:
#     df_des[y] = df[df['yyyy'] == y].describe(include = 'all')

# for y in ys:
#     print('V - ' + y + ' - V')
#     display (df_des[y])

# %%
plt.figure(figsize = (12, 8))


# for y in ys:
#     plt.plot(df[df['yyyy'] == y]['mm'], df[df['yyyy'] == y]['no_of_rainy_days'], label = y)

# plt.title('Rain')
# plt.legend(bbox_to_anchor = (1.04, 0.5), loc = "center left")
# plt.show()

fig = plt.figure(figsize = (12, 8))
ax = plt.gca()
rg = range(2013,2024)
df2 = df.copy()
df2['yyyymm'] = df2['yyyy'].copy().astype(str) + df2['mm'].copy().astype(str)
df2['yyyymm'] = df2['yyyymm'].astype(int)
df2 = df2[(df2['yyyymm'] >= 201300) & (df2['yyyymm'] <= 202312)]
# display(df2)
plt.plot(df2['yyyymm'], df2['no_of_rainy_days'])

plt.figure(figsize = (12, 8))
sns.scatterplot(data = df2, x = 'mm', y = 'no_of_rainy_days', hue = 'yyyy')
# sns.lineplot(data = df.groupby(by = 'mmm'), x = 'yyyy', ax = ax)
# Out:
# <Axes: xlabel='mm', ylabel='no_of_rainy_days'>
