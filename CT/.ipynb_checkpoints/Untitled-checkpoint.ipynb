# %%
import matplotlib.pyplot as plt
from scipy.signal import tf2zpk
import numpy as np
import control as ct

# %%
def pspl():
    print('\n-:-')

# %%
w_n = 4
zeta = 0.5

# Define the transfer function (assuming a SISO system)
output_f = [4.182, 0, 10.25]
input_f = [2.3, 2.091, 7.172, 5.123, 0]

# Extract poles and zeros
z, p, k = tf2zpk(output_f, input_f)
pspl()
print(z)
print(p)
print(k)
# Out:
# -:-
# [-0.+1.56556073j  0.-1.56556073j]
# [-0.08273878+1.72868658j -0.08273878-1.72868658j -0.74365287+0.j
#   0.        +0.j        ]
# 1.8182608695652176

# %%
sys = ct.tf(output_f, input_f)
pspl()
print(sys)

pspl()
print(sys.poles)
# Out:
# -:-
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#
#             4.182 s^2 + 10.25
# -----------------------------------------
# 2.3 s^4 + 2.091 s^3 + 7.172 s^2 + 5.123 s
#
#
# -:-
# <bound method TransferFunction.poles of TransferFunction(array([ 4.182,  0.   , 10.25 ]), array([2.3  , 2.091, 7.172, 5.123, 0.   ]))>

# %%
# Plot poles and zeros
plt.figure(figsize=(15, 15))
plt.plot(np.real(z), np.imag(z), 'o', markersize=15, label='Zeros')
plt.plot(np.real(p), np.imag(p), 'x', markersize=15, label='Poles')

# Add labels and title
plt.xlabel('Real')
plt.ylabel('Imaginary')
plt.title('Poles and Zeros of the Transfer Function')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Convert to polar coordinates (magnitude and phase)
z_mag, z_phase = np.abs(z), np.angle(z)
p_mag, p_phase = np.abs(p), np.angle(p)

# Generate angles for the polar grid (0 to 2*pi)
theta = np.linspace(0, 2*np.pi, 200)

# Create the polar grid manually
plt.figure(figsize=(15, 15))
plt.polar(theta, np.ones_like(theta), color='lightgray', linestyle='--', linewidth=0.5)  # Circles

# Plot poles and zeros
plt.polar(z_phase, z_mag, 'o', markersize=15, label='Zeros')
plt.polar(p_phase, p_mag, 'x', markersize=15, label='Poles')

# Add labels and title
plt.xlabel('Angle (rad)')
plt.ylabel('Magnitude')
plt.title('Poles and Zeros on Polar Grid (Bode Plot)')

# Legend
plt.legend()
plt.show()
